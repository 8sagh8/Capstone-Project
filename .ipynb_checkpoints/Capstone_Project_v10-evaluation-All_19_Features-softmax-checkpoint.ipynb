# %% [markdown]
# # Conclusion:
#
# - Import data from file 'postings_v3.csv'
# - All values are filled except 'salary_range'
#
# - Models build in here
#     - Neural Network
#     - Logistic Regression
#     - Decision Trees
#     - Random Forest
#     - Support Vector Machines (SVMs)
#
# - for Neural Network Model Evaluation log, excel 'NN Model Report' is created
#
# - So far the best Model is:
#     - Neural Network Model
#     - Attempt#
#     - 1st Layer Dense:
#     - 2nd Layer Dense:
#     - epochs:
#
#     - Accuracy
#     - Precision
#     - Recall
#     - F1 Score

# %% [markdown]
# # Import Libraries & Packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_csv("./postings_v4.csv")
df.head(3)
# Out:
#                                        title   salary_range  \
# 0                           Marketing Intern  Not Available
# 1  Customer Service - Cloud Video Production             90
# 2    Commissioning Machinery Assistant (CMA)  Not Available
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
#
#                                             benefits  telecommuting  \
# 0                                 No Listed Benefits              0
# 1  What you will get from usThrough being part of...              0
# 2                                 No Listed Benefits              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
# 2                 1              0         Unknown      Not Applicable
#
#   required_education                   industry          function  fraudulent  \
# 0            Unknown                    Unknown         Marketing           0
# 1            Unknown  Marketing and Advertising  Customer Service           0
# 2            Unknown                    Unknown         Assistant           0
#
#   Country State       City  has_company_profile  has_required_education  \
# 0      US    NY   New York                    1                       0
# 1      NZ         Auckland                    1                       0
# 2      US    IA      Wever                    1                       0
#
#    has_salary
# 0           0
# 1           1
# 2           0

# %%
df.shape
# Out:
# (17880, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   17880 non-null  object
#  1   salary_range            17880 non-null  object
#  2   description             17880 non-null  object
#  3   requirements            17880 non-null  object
#  4   benefits                17880 non-null  object
#  5   telecommuting           17880 non-null  int64
#  6   has_company_logo        17880 non-null  int64
#  7   has_questions           17880 non-null  int64
#  8   employment_type         17880 non-null  object
#  9   required_experience     17880 non-null  object
#  10  required_education      17880 non-null  object
#  11  industry                17880 non-null  object
#  12  function                17880 non-null  object
#  13  fraudulent              17880 non-null  int64
#  14  Country                 17880 non-null  object
#  15  State                   17880 non-null  object
#  16  City                    17880 non-null  object
#  17  has_company_profile     17880 non-null  int64
#  18  has_required_education  17880 non-null  int64
#  19  has_salary              17880 non-null  int64
# dtypes: int64(7), object(13)
# memory usage: 2.7+ MB

# %%
# Percentages of Null values in dataframe df
round(df.isnull().mean() * 100, 2)
# Out:
# title                     0.0
# salary_range              0.0
# description               0.0
# requirements              0.0
# benefits                  0.0
# telecommuting             0.0
# has_company_logo          0.0
# has_questions             0.0
# employment_type           0.0
# required_experience       0.0
# required_education        0.0
# industry                  0.0
# function                  0.0
# fraudulent                0.0
# Country                   0.0
# State                     0.0
# City                      0.0
# has_company_profile       0.0
# has_required_education    0.0
# has_salary                0.0
# dtype: float64

# %%
# dataset is unbalanced

#  total number of real and fake postings in dataframe
df['fraudulent'].value_counts()
# Out:
# 0    17014
# 1      866
# Name: fraudulent, dtype: int64

# %%
# # create new csv file

# df.to_csv('postings_v3.csv', index=False)

# %% [markdown]
# # Process of Vectorization

# %%
import regex as re
import regex as re

df['title'] = df['title'].str.lower()
df['title'] = df['title'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['salary_range'] = df['salary_range'].str.lower()
df['salary_range'] = df['salary_range'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['description'] = df['description'].str.lower()
df['description'] = df['description'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['requirements'] = df['requirements'].str.lower()
df['requirements'] = df['requirements'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['benefits'] = df['benefits'].str.lower()
df['benefits'] = df['benefits'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['employment_type'] = df['employment_type'].str.lower()
df['employment_type'] = df['employment_type'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['required_experience'] = df['required_experience'].str.lower()
df['required_experience'] = df['required_experience'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['required_education'] = df['required_education'].str.lower()
df['required_education'] = df['required_education'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['industry'] = df['industry'].str.lower()
df['industry'] = df['industry'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['function'] = df['function'].str.lower()
df['function'] = df['function'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['Country'] = df['Country'].str.lower()
df['Country'] = df['Country'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['State'] = df['State'].str.lower()
df['State'] = df['State'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['City'] = df['City'].str.lower()
df['City'] = df['City'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

# %%
#Tokenizing description series
import nltk 
from nltk.tokenize import word_tokenize

df['title'] = df['title'].apply(word_tokenize)
df['salary_range'] = df['salary_range'].apply(word_tokenize)
df['description'] = df['description'].apply(word_tokenize)
df['requirements']  = df['requirements'] .apply(word_tokenize)
df['benefits'] = df['benefits'].apply(word_tokenize)
df['employment_type'] = df['employment_type'].apply(word_tokenize)
df['required_experience'] = df['required_experience'].apply(word_tokenize)
df['required_education'] = df['required_education'].apply(word_tokenize)
df['industry'] = df['industry'].apply(word_tokenize)
df['function'] = df['function'].apply(word_tokenize)
df['Country'] = df['Country'].apply(word_tokenize)
df['State'] = df['State'].apply(word_tokenize)
df['City'] = df['City'].apply(word_tokenize)

# %%
#remove stopwords from description
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

df['title'] = df['title'].apply(lambda x: [word for word in x if word not in stop_words])
df['salary_range'] = df['salary_range'].apply(lambda x: [word for word in x if word not in stop_words])
df['description'] = df['description'].apply(lambda x: [word for word in x if word not in stop_words])
df['requirements']  = df['requirements'] .apply(lambda x: [word for word in x if word not in stop_words])
df['benefits'] = df['benefits'].apply(lambda x: [word for word in x if word not in stop_words])
df['employment_type'] = df['employment_type'].apply(lambda x: [word for word in x if word not in stop_words])
df['required_experience'] = df['required_experience'].apply(lambda x: [word for word in x if word not in stop_words])
df['required_education'] = df['required_education'].apply(lambda x: [word for word in x if word not in stop_words])
df['industry'] = df['industry'].apply(lambda x: [word for word in x if word not in stop_words])
df['function'] = df['function'].apply(lambda x: [word for word in x if word not in stop_words])
df['Country'] = df['Country'].apply(lambda x: [word for word in x if word not in stop_words])
df['State'] = df['State'].apply(lambda x: [word for word in x if word not in stop_words])
df['City'] = df['City'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
#join string back for analysis

def combine_words(words_list):
    # Combine the words into a single string with spaces
    combined_string = " ".join(words_list)
    
    return combined_string

df['title'] = df['title'].apply(combine_words)
df['salary_range'] = df['salary_range'].apply(combine_words)
df['description'] = df['description'].apply(combine_words)
df['requirements']  = df['requirements'] .apply(combine_words)
df['benefits'] = df['benefits'].apply(combine_words)
df['employment_type'] = df['employment_type'].apply(combine_words)
df['required_experience'] = df['required_experience'].apply(combine_words)
df['required_education'] = df['required_education'].apply(combine_words)
df['industry'] = df['industry'].apply(combine_words)
df['function'] = df['function'].apply(combine_words)
df['Country'] = df['Country'].apply(combine_words)
df['State'] = df['State'].apply(combine_words)
df['City'] = df['City'].apply(combine_words)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=440)

df['title'] = cv.fit_transform( df['title'] ).toarray()
df['salary_range'] = cv.fit_transform( df['salary_range'] ).toarray()
df['description'] = cv.fit_transform( df['description'] ).toarray()
df['requirements']  = cv.fit_transform( df['requirements'] ).toarray()
df['benefits'] = cv.fit_transform( df['benefits'] ).toarray()
df['employment_type'] = cv.fit_transform( df['employment_type'] ).toarray()
df['required_experience'] = cv.fit_transform( df['required_experience'] ).toarray()
df['required_education'] = cv.fit_transform( df['required_education'] ).toarray()
df['industry'] = cv.fit_transform( df['industry'] ).toarray()
df['function'] = cv.fit_transform( df['function'] ).toarray()
df['Country'] = cv.fit_transform( df['Country'] ).toarray()
df['State'] = cv.fit_transform( df['State'] ).toarray()
df['City'] = cv.fit_transform( df['City'] ).toarray()

# %% [markdown]
# # SMOTE

# %% [markdown]
# # Using 19 Features

# %%
X = df[['title', 'salary_range', 'description', 'requirements', 'benefits',
        'telecommuting', 'has_company_logo', 'has_questions',
        'employment_type', 'required_experience', 'required_education',
        'industry', 'function', 'Country', 'State', 'City', 
        'has_company_profile', 'has_required_education', 'has_salary'
        ]]



y = df['fraudulent']

# %%
from collections import Counter
Counter(y)
# Out:
# Counter({0: 17014, 1: 866})

# %%
from imblearn.over_sampling import SMOTE
smo = SMOTE(random_state=42)
X_smo,y_smo = smo.fit_resample(X,y)

# %%
Counter(y_smo)
# Out:
# Counter({0: 17014, 1: 17014})

# %% [markdown]
# # Data Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_smo,y_smo, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Building Model

# %% [markdown]
# ### Functions

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

def get_model_initialization(first_dense, second_dense):
    # Initialize model
    model = Sequential()

    # Add first layer with input dimension of 19 (number of features)
    model.add(Dense(first_dense, input_dim=19, activation='relu'))

    # Add second layer
    model.add(Dense(second_dense, activation='relu'))

    # Add output layer with sigmoid activation function
    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model


def get_Model_score (x_test_set, y_test_set, attmpt):
    # Predict the target values for the test data
    y_pred = model.predict(x_test_set)

    # Convert the predicted probabilities to binary labels
    y_pred = [1 if y>0.5 else 0 for y in y_pred]

    # Calculate accuracy
    accuracy = accuracy_score(y_test_set, y_pred)

    # Calculate confusion matrix
    cm = confusion_matrix(y_test_set, y_pred)

    # Calculate precision
    precision = precision_score(y_test_set, y_pred)

    # Calculate recall
    recall = recall_score(y_test_set, y_pred)

    # Calculate F1 score
    f1 = f1_score(y_test_set, y_pred)
    
    print("\nAttempt #", attmpt)
    print("Accuracy: ", accuracy)
    print("Confusion Matrix: \n", cm)
    print("Precision: ", precision)
    print("Recall: ", recall)
    print("F1 Score: ", f1)

# %% [markdown]
# # Neural Network

# %%
from keras.layers import Dense

# %%
from keras.models import Sequential

# %% [markdown]
# ## Attempt# 01

# %%
first_dense = 20
second_dense = 8

model = get_model_initialization(first_dense, second_dense)

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10)

get_Model_score(X_test, y_test, 1)
# Out:
# Epoch 1/50
# 2723/2723 [==============================] - 15s 5ms/step - loss: 0.4776 - accuracy: 0.7711
# Epoch 2/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4335 - accuracy: 0.7866
# Epoch 3/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4224 - accuracy: 0.7907
# Epoch 4/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4158 - accuracy: 0.7937
# Epoch 5/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4113 - accuracy: 0.7959
# Epoch 6/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4083 - accuracy: 0.7965
# Epoch 7/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4059 - accuracy: 0.7992
# Epoch 8/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4035 - accuracy: 0.8004
# Epoch 9/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4018 - accuracy: 0.7992
# Epoch 10/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4005 - accuracy: 0.8027
# Epoch 11/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3991 - accuracy: 0.8025
# Epoch 12/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3985 - accuracy: 0.8030
# Epoch 13/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3978 - accuracy: 0.8019
# Epoch 14/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3971 - accuracy: 0.8029
# Epoch 15/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3972 - accuracy: 0.8015
# Epoch 16/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3965 - accuracy: 0.8021
# Epoch 17/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3962 - accuracy: 0.8018
# Epoch 18/50
# 2723/2723 [==============================] - 15s 6ms/step - loss: 0.3957 - accuracy: 0.8042
# Epoch 19/50
# 2723/2723 [==============================] - 15s 5ms/step - loss: 0.3952 - accuracy: 0.8043
# Epoch 20/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3948 - accuracy: 0.8049
# Epoch 21/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3941 - accuracy: 0.8039
# Epoch 22/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3941 - accuracy: 0.8060
# Epoch 23/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3937 - accuracy: 0.8053
# Epoch 24/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3929 - accuracy: 0.8033
# Epoch 25/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3931 - accuracy: 0.8066
# Epoch 26/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3930 - accuracy: 0.8052
# Epoch 27/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3926 - accuracy: 0.8052
# Epoch 28/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3925 - accuracy: 0.8038
# Epoch 29/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3926 - accuracy: 0.8040
# Epoch 30/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3925 - accuracy: 0.8057
# Epoch 31/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3923 - accuracy: 0.8043
# Epoch 32/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3920 - accuracy: 0.8052
# Epoch 33/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3916 - accuracy: 0.8066
# Epoch 34/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3915 - accuracy: 0.8045
# Epoch 35/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3912 - accuracy: 0.8060
# Epoch 36/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3913 - accuracy: 0.8062
# Epoch 37/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3912 - accuracy: 0.8055
# Epoch 38/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3905 - accuracy: 0.8057
# Epoch 39/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3909 - accuracy: 0.8041
# Epoch 40/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3903 - accuracy: 0.8038
# Epoch 41/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3905 - accuracy: 0.8054
# Epoch 42/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3900 - accuracy: 0.8052
# Epoch 43/50
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3900 - accuracy: 0.8049
# Epoch 44/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3899 - accuracy: 0.8066
# Epoch 45/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3892 - accuracy: 0.8052
# Epoch 46/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3896 - accuracy: 0.8065
# Epoch 47/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3895 - accuracy: 0.8051
# Epoch 48/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3893 - accuracy: 0.8055
# Epoch 49/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3893 - accuracy: 0.8041
# Epoch 50/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3892 - accuracy: 0.8070
# 213/213 [==============================] - 1s 3ms/step
#
# Attempt # 1
# Accuracy:  0.8091389950044079
# Confusion Matrix:
#  [[2631  765]
#  [ 534 2876]]
# Precision:  0.7898928865696238
# Recall:  0.8434017595307918
# F1 Score:  0.8157708126506878

# %% [markdown]
# ## Attempt# 02

# %%
first_dense = 20
second_dense = 10

model = get_model_initialization(first_dense, second_dense)

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10)

get_Model_score(X_test, y_test, 2)
# Out:
# Epoch 1/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.4780 - accuracy: 0.7753
# Epoch 2/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4281 - accuracy: 0.7920
# Epoch 3/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.4167 - accuracy: 0.7952
# Epoch 4/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4113 - accuracy: 0.7949
# Epoch 5/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4081 - accuracy: 0.7966
# Epoch 6/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.4060 - accuracy: 0.7977
# Epoch 7/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4039 - accuracy: 0.7977
# Epoch 8/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4029 - accuracy: 0.7991
# Epoch 9/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4015 - accuracy: 0.7984
# Epoch 10/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4003 - accuracy: 0.7989
# Epoch 11/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3993 - accuracy: 0.7995
# Epoch 12/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3989 - accuracy: 0.7998
# Epoch 13/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3978 - accuracy: 0.7996
# Epoch 14/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3972 - accuracy: 0.7999
# Epoch 15/50
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3961 - accuracy: 0.8005
# Epoch 16/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3963 - accuracy: 0.7992
# Epoch 17/50
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3964 - accuracy: 0.8010
# Epoch 18/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3946 - accuracy: 0.8028
# Epoch 19/50
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3947 - accuracy: 0.8021
# Epoch 20/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3945 - accuracy: 0.8021
# Epoch 21/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3946 - accuracy: 0.8032
# Epoch 22/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3939 - accuracy: 0.8029
# Epoch 23/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3937 - accuracy: 0.8027
# Epoch 24/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3929 - accuracy: 0.8036
# Epoch 25/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3928 - accuracy: 0.8025
# Epoch 26/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3926 - accuracy: 0.8030
# Epoch 27/50
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3923 - accuracy: 0.8026
# Epoch 28/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3924 - accuracy: 0.8032
# Epoch 29/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3919 - accuracy: 0.8031
# Epoch 30/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3915 - accuracy: 0.8053
# Epoch 31/50
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3912 - accuracy: 0.8057
# Epoch 32/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3913 - accuracy: 0.8035
# Epoch 33/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3912 - accuracy: 0.8052
# Epoch 34/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3913 - accuracy: 0.8050
# Epoch 35/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3904 - accuracy: 0.8027
# Epoch 36/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3905 - accuracy: 0.8063
# Epoch 37/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3903 - accuracy: 0.8064
# Epoch 38/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3899 - accuracy: 0.8062
# Epoch 39/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3900 - accuracy: 0.8057
# Epoch 40/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3900 - accuracy: 0.8039
# Epoch 41/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3898 - accuracy: 0.8062
# Epoch 42/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3897 - accuracy: 0.8053
# Epoch 43/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3901 - accuracy: 0.8042
# Epoch 44/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3898 - accuracy: 0.8062
# Epoch 45/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3897 - accuracy: 0.8050
# Epoch 46/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3898 - accuracy: 0.8045
# Epoch 47/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3889 - accuracy: 0.8040
# Epoch 48/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3892 - accuracy: 0.8058
# Epoch 49/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3888 - accuracy: 0.8048
# Epoch 50/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3891 - accuracy: 0.8050
# 213/213 [==============================] - 1s 5ms/step
#
# Attempt # 2
# Accuracy:  0.8051719071407581
# Confusion Matrix:
#  [[2594  802]
#  [ 524 2886]]
# Precision:  0.7825379609544468
# Recall:  0.8463343108504399
# F1 Score:  0.8131868131868131

# %% [markdown]
# ## Attempt# 03

# %%
first_dense = 25
second_dense = 9

model = get_model_initialization(first_dense, second_dense)

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=10)

get_Model_score(X_test, y_test, 3)
# Out:
# Epoch 1/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.4758 - accuracy: 0.7700
# Epoch 2/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4268 - accuracy: 0.7889
# Epoch 3/100
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.4161 - accuracy: 0.7917
# Epoch 4/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4096 - accuracy: 0.7948
# Epoch 5/100
# 2723/2723 [==============================] - 15s 5ms/step - loss: 0.4053 - accuracy: 0.7967
# Epoch 6/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4033 - accuracy: 0.7992
# Epoch 7/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4005 - accuracy: 0.8001
# Epoch 8/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3990 - accuracy: 0.7985
# Epoch 9/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3976 - accuracy: 0.8005
# Epoch 10/100
# 2723/2723 [==============================] - 16s 6ms/step - loss: 0.3967 - accuracy: 0.8020
# Epoch 11/100
# 2723/2723 [==============================] - 17s 6ms/step - loss: 0.3965 - accuracy: 0.8012
# Epoch 12/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3957 - accuracy: 0.8001
# Epoch 13/100
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3944 - accuracy: 0.7995
# Epoch 14/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3952 - accuracy: 0.8029
# Epoch 15/100
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3943 - accuracy: 0.8035
# Epoch 16/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3940 - accuracy: 0.8012
# Epoch 17/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3935 - accuracy: 0.8036
# Epoch 18/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3935 - accuracy: 0.8025
# Epoch 19/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3925 - accuracy: 0.8043
# Epoch 20/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3928 - accuracy: 0.8027
# Epoch 21/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3925 - accuracy: 0.8049
# Epoch 22/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3919 - accuracy: 0.8037
# Epoch 23/100
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3911 - accuracy: 0.8046
# Epoch 24/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3914 - accuracy: 0.8028
# Epoch 25/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3911 - accuracy: 0.8045
# Epoch 26/100
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3909 - accuracy: 0.8043
# Epoch 27/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3911 - accuracy: 0.8060
# Epoch 28/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3909 - accuracy: 0.8055
# Epoch 29/100
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3911 - accuracy: 0.8044
# Epoch 30/100
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3905 - accuracy: 0.8045
# Epoch 31/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3900 - accuracy: 0.8056
# Epoch 32/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3903 - accuracy: 0.8041
# Epoch 33/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3905 - accuracy: 0.8050
# Epoch 34/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3897 - accuracy: 0.8057
# Epoch 35/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3895 - accuracy: 0.8041
# Epoch 36/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3895 - accuracy: 0.8038
# Epoch 37/100
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3893 - accuracy: 0.8063
# Epoch 38/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3892 - accuracy: 0.8045
# Epoch 39/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3887 - accuracy: 0.8067
# Epoch 40/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3892 - accuracy: 0.8052
# Epoch 41/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3882 - accuracy: 0.8059
# Epoch 42/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3882 - accuracy: 0.8068
# Epoch 43/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3884 - accuracy: 0.8067
# Epoch 44/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3884 - accuracy: 0.8064
# Epoch 45/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3882 - accuracy: 0.8041
# Epoch 46/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3882 - accuracy: 0.8069
# Epoch 47/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3878 - accuracy: 0.8056
# Epoch 48/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3879 - accuracy: 0.8058
# Epoch 49/100
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3879 - accuracy: 0.8039
# Epoch 50/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3876 - accuracy: 0.8063
# Epoch 51/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3878 - accuracy: 0.8053
# Epoch 52/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3876 - accuracy: 0.8045
# Epoch 53/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3874 - accuracy: 0.8057
# Epoch 54/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3876 - accuracy: 0.8063
# Epoch 55/100
# 2723/2723 [==============================] - 15s 6ms/step - loss: 0.3872 - accuracy: 0.8065
# Epoch 56/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3876 - accuracy: 0.8037
# Epoch 57/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3871 - accuracy: 0.8045
# Epoch 58/100
# 2723/2723 [==============================] - 15s 6ms/step - loss: 0.3869 - accuracy: 0.8069
# Epoch 59/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3870 - accuracy: 0.8049
# Epoch 60/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3868 - accuracy: 0.8071
# Epoch 61/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3867 - accuracy: 0.8064
# Epoch 62/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3866 - accuracy: 0.8080
# Epoch 63/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3870 - accuracy: 0.8061
# Epoch 64/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3864 - accuracy: 0.8062
# Epoch 65/100
# 2723/2723 [==============================] - 15s 5ms/step - loss: 0.3865 - accuracy: 0.8055
# Epoch 66/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3866 - accuracy: 0.8059
# Epoch 67/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3864 - accuracy: 0.8084
# Epoch 68/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3865 - accuracy: 0.8064
# Epoch 69/100
# 2723/2723 [==============================] - 15s 5ms/step - loss: 0.3862 - accuracy: 0.8067
# Epoch 70/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3865 - accuracy: 0.8080
# Epoch 71/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3857 - accuracy: 0.8063
# Epoch 72/100
# 2723/2723 [==============================] - 15s 5ms/step - loss: 0.3860 - accuracy: 0.8074
# Epoch 73/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3859 - accuracy: 0.8079
# Epoch 74/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3858 - accuracy: 0.8074
# Epoch 75/100
# 2723/2723 [==============================] - 15s 6ms/step - loss: 0.3856 - accuracy: 0.8079
# Epoch 76/100
# 2723/2723 [==============================] - 19s 7ms/step - loss: 0.3859 - accuracy: 0.8065
# Epoch 77/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3855 - accuracy: 0.8081
# Epoch 78/100
# 2723/2723 [==============================] - 24s 9ms/step - loss: 0.3854 - accuracy: 0.8085
# Epoch 79/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3854 - accuracy: 0.8075
# Epoch 80/100
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3859 - accuracy: 0.8061
# Epoch 81/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3857 - accuracy: 0.8070
# Epoch 82/100
# 2723/2723 [==============================] - 10s 4ms/step - loss: 0.3855 - accuracy: 0.8084
# Epoch 83/100
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3859 - accuracy: 0.8067
# Epoch 84/100
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3852 - accuracy: 0.8055
# Epoch 85/100
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3850 - accuracy: 0.8082
# Epoch 86/100
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3859 - accuracy: 0.8072
# Epoch 87/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3853 - accuracy: 0.8069
# Epoch 88/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3852 - accuracy: 0.8074
# Epoch 89/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3856 - accuracy: 0.8052
# Epoch 90/100
# 2723/2723 [==============================] - 15s 5ms/step - loss: 0.3853 - accuracy: 0.8085
# Epoch 91/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3852 - accuracy: 0.8077
# Epoch 92/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3852 - accuracy: 0.8075
# Epoch 93/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3851 - accuracy: 0.8074
# Epoch 94/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3848 - accuracy: 0.8065
# Epoch 95/100
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3852 - accuracy: 0.8071
# Epoch 96/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3856 - accuracy: 0.8062
# Epoch 97/100
# 2723/2723 [==============================] - 15s 5ms/step - loss: 0.3852 - accuracy: 0.8063
# Epoch 98/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3855 - accuracy: 0.8063
# Epoch 99/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3845 - accuracy: 0.8091
# Epoch 100/100
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3852 - accuracy: 0.8071
# 213/213 [==============================] - 2s 5ms/step
#
# Attempt # 3
# Accuracy:  0.8100205700852189
# Confusion Matrix:
#  [[2688  708]
#  [ 585 2825]]
# Precision:  0.7996037362015285
# Recall:  0.8284457478005866
# F1 Score:  0.8137692640069134

# %% [markdown]
# ## Attempt# 04

# %%
first_dense = 20
second_dense = 6

model = get_model_initialization(first_dense, second_dense)


# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10)

get_Model_score(X_test, y_test, 4)
# Out:
# Epoch 1/50
# 2723/2723 [==============================] - 14s 4ms/step - loss: 0.4738 - accuracy: 0.7672
# Epoch 2/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.4233 - accuracy: 0.7897
# Epoch 3/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4135 - accuracy: 0.7968
# Epoch 4/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4091 - accuracy: 0.7971
# Epoch 5/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.4055 - accuracy: 0.7982
# Epoch 6/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.4036 - accuracy: 0.7989
# Epoch 7/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.4026 - accuracy: 0.7983
# Epoch 8/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.4011 - accuracy: 0.7986
# Epoch 9/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.4003 - accuracy: 0.7991
# Epoch 10/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3993 - accuracy: 0.7992
# Epoch 11/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3987 - accuracy: 0.7990
# Epoch 12/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3978 - accuracy: 0.8001
# Epoch 13/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3972 - accuracy: 0.8013
# Epoch 14/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3966 - accuracy: 0.8007
# Epoch 15/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3966 - accuracy: 0.7996
# Epoch 16/50
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3963 - accuracy: 0.8014
# Epoch 17/50
# 2723/2723 [==============================] - 9s 3ms/step - loss: 0.3959 - accuracy: 0.8023
# Epoch 18/50
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3954 - accuracy: 0.8013
# Epoch 19/50
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3954 - accuracy: 0.8003
# Epoch 20/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3945 - accuracy: 0.8020
# Epoch 21/50
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3940 - accuracy: 0.8028
# Epoch 22/50
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3939 - accuracy: 0.8028
# Epoch 23/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3935 - accuracy: 0.8027
# Epoch 24/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3932 - accuracy: 0.8036
# Epoch 25/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3933 - accuracy: 0.8030
# Epoch 26/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3928 - accuracy: 0.8048
# Epoch 27/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3930 - accuracy: 0.8031
# Epoch 28/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3930 - accuracy: 0.8031
# Epoch 29/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3922 - accuracy: 0.8035
# Epoch 30/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3918 - accuracy: 0.8042
# Epoch 31/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3921 - accuracy: 0.8027
# Epoch 32/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3919 - accuracy: 0.8034
# Epoch 33/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3921 - accuracy: 0.8034
# Epoch 34/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3918 - accuracy: 0.8047
# Epoch 35/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3919 - accuracy: 0.8041
# Epoch 36/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3916 - accuracy: 0.8032
# Epoch 37/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3916 - accuracy: 0.8039
# Epoch 38/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3915 - accuracy: 0.8039
# Epoch 39/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3915 - accuracy: 0.8018
# Epoch 40/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3913 - accuracy: 0.8014
# Epoch 41/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3911 - accuracy: 0.8049
# Epoch 42/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3910 - accuracy: 0.8023
# Epoch 43/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3909 - accuracy: 0.8020
# Epoch 44/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3909 - accuracy: 0.8022
# Epoch 45/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3909 - accuracy: 0.8037
# Epoch 46/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3907 - accuracy: 0.8052
# Epoch 47/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3902 - accuracy: 0.8045
# Epoch 48/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3902 - accuracy: 0.8028
# Epoch 49/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3900 - accuracy: 0.8050
# Epoch 50/50
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.3900 - accuracy: 0.8041
# 213/213 [==============================] - 0s 1ms/step
#
# Attempt # 4
# Accuracy:  0.8085512782838672
# Confusion Matrix:
#  [[2611  785]
#  [ 518 2892]]
# Precision:  0.7865107424530867
# Recall:  0.8480938416422288
# F1 Score:  0.8161422322562437

# %% [markdown]
# ## Attempt# 05

# %%
first_dense = 20
second_dense = 7

model = get_model_initialization(first_dense, second_dense)

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10)

get_Model_score(X_test, y_test, 5)
# Out:
# Epoch 1/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4714 - accuracy: 0.7756
# Epoch 2/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.4316 - accuracy: 0.7899
# Epoch 3/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4202 - accuracy: 0.7916
# Epoch 4/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4151 - accuracy: 0.7933
# Epoch 5/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4112 - accuracy: 0.7953
# Epoch 6/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4084 - accuracy: 0.7960
# Epoch 7/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.4056 - accuracy: 0.7965
# Epoch 8/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4043 - accuracy: 0.7950
# Epoch 9/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.4029 - accuracy: 0.7981
# Epoch 10/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4016 - accuracy: 0.7983
# Epoch 11/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.4012 - accuracy: 0.7996
# Epoch 12/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4005 - accuracy: 0.7996
# Epoch 13/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3998 - accuracy: 0.8014
# Epoch 14/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3995 - accuracy: 0.8010
# Epoch 15/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3987 - accuracy: 0.8007
# Epoch 16/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3982 - accuracy: 0.8015
# Epoch 17/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3982 - accuracy: 0.8016
# Epoch 18/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3973 - accuracy: 0.8012
# Epoch 19/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3974 - accuracy: 0.8017
# Epoch 20/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3970 - accuracy: 0.8020
# Epoch 21/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3961 - accuracy: 0.8017
# Epoch 22/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3962 - accuracy: 0.8021
# Epoch 23/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3959 - accuracy: 0.8016
# Epoch 24/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3961 - accuracy: 0.8030
# Epoch 25/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3954 - accuracy: 0.8034
# Epoch 26/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3953 - accuracy: 0.8037
# Epoch 27/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3948 - accuracy: 0.8026
# Epoch 28/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3943 - accuracy: 0.8023
# Epoch 29/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3942 - accuracy: 0.8040
# Epoch 30/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3942 - accuracy: 0.8036
# Epoch 31/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3938 - accuracy: 0.8039
# Epoch 32/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3940 - accuracy: 0.8045
# Epoch 33/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3938 - accuracy: 0.8035
# Epoch 34/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3937 - accuracy: 0.8029
# Epoch 35/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3936 - accuracy: 0.8038
# Epoch 36/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3933 - accuracy: 0.8027
# Epoch 37/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3932 - accuracy: 0.8040
# Epoch 38/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3925 - accuracy: 0.8042
# Epoch 39/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3930 - accuracy: 0.8050
# Epoch 40/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3924 - accuracy: 0.8055
# Epoch 41/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3924 - accuracy: 0.8051
# Epoch 42/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3921 - accuracy: 0.8045
# Epoch 43/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3930 - accuracy: 0.8055
# Epoch 44/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3925 - accuracy: 0.8049
# Epoch 45/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3916 - accuracy: 0.8059
# Epoch 46/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3917 - accuracy: 0.8056
# Epoch 47/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3916 - accuracy: 0.8064
# Epoch 48/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3916 - accuracy: 0.8053
# Epoch 49/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3912 - accuracy: 0.8061
# Epoch 50/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3917 - accuracy: 0.8058
# 213/213 [==============================] - 0s 1ms/step
#
# Attempt # 5
# Accuracy:  0.8076697032030561
# Confusion Matrix:
#  [[2960  436]
#  [ 873 2537]]
# Precision:  0.853346787756475
# Recall:  0.7439882697947214
# F1 Score:  0.7949240169199436

# %% [markdown]
# ## Attempt# 06

# %%
first_dense = 25
second_dense = 7

model = get_model_initialization(first_dense, second_dense)

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10)

get_Model_score(X_test, y_test, 6)
# Out:
# Epoch 1/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.4718 - accuracy: 0.7759
# Epoch 2/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4273 - accuracy: 0.7907
# Epoch 3/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4155 - accuracy: 0.7926
# Epoch 4/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.4101 - accuracy: 0.7936
# Epoch 5/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4053 - accuracy: 0.7970
# Epoch 6/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4031 - accuracy: 0.7983
# Epoch 7/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4006 - accuracy: 0.8001
# Epoch 8/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3992 - accuracy: 0.8013
# Epoch 9/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3979 - accuracy: 0.8010
# Epoch 10/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3973 - accuracy: 0.8006
# Epoch 11/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3963 - accuracy: 0.8023
# Epoch 12/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3960 - accuracy: 0.8020
# Epoch 13/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3951 - accuracy: 0.8019
# Epoch 14/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3945 - accuracy: 0.8021
# Epoch 15/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3947 - accuracy: 0.8029
# Epoch 16/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3941 - accuracy: 0.8021
# Epoch 17/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3936 - accuracy: 0.8028
# Epoch 18/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3933 - accuracy: 0.8012
# Epoch 19/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3935 - accuracy: 0.8009
# Epoch 20/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3932 - accuracy: 0.8000
# Epoch 21/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3926 - accuracy: 0.8039
# Epoch 22/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3932 - accuracy: 0.8029
# Epoch 23/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3924 - accuracy: 0.8032
# Epoch 24/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3922 - accuracy: 0.8041
# Epoch 25/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3924 - accuracy: 0.8015
# Epoch 26/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3916 - accuracy: 0.8027
# Epoch 27/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3918 - accuracy: 0.8039
# Epoch 28/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3913 - accuracy: 0.8053
# Epoch 29/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3912 - accuracy: 0.8037
# Epoch 30/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3913 - accuracy: 0.8037
# Epoch 31/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3911 - accuracy: 0.8035
# Epoch 32/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3906 - accuracy: 0.8044
# Epoch 33/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3912 - accuracy: 0.8032
# Epoch 34/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3905 - accuracy: 0.8038
# Epoch 35/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3906 - accuracy: 0.8042
# Epoch 36/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3906 - accuracy: 0.8031
# Epoch 37/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3905 - accuracy: 0.8038
# Epoch 38/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3907 - accuracy: 0.8016
# Epoch 39/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3901 - accuracy: 0.8048
# Epoch 40/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3902 - accuracy: 0.8046
# Epoch 41/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3897 - accuracy: 0.8043
# Epoch 42/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3901 - accuracy: 0.8037
# Epoch 43/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3898 - accuracy: 0.8031
# Epoch 44/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3902 - accuracy: 0.8054
# Epoch 45/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3893 - accuracy: 0.8038
# Epoch 46/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3895 - accuracy: 0.8039
# Epoch 47/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3889 - accuracy: 0.8057
# Epoch 48/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3897 - accuracy: 0.8023
# Epoch 49/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3892 - accuracy: 0.8067
# Epoch 50/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3892 - accuracy: 0.8060
# 213/213 [==============================] - 0s 1ms/step
#
# Attempt # 6
# Accuracy:  0.8103144284454893
# Confusion Matrix:
#  [[2635  761]
#  [ 530 2880]]
# Precision:  0.7909914858555342
# Recall:  0.844574780058651
# F1 Score:  0.8169054034888669

# %% [markdown]
# ## Attempt# 07

# %%
first_dense = 25
second_dense = 6

model = get_model_initialization(first_dense, second_dense)

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10)

get_Model_score(X_test, y_test, 7)
# Out:
# Epoch 1/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.4777 - accuracy: 0.7699
# Epoch 2/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4317 - accuracy: 0.7888
# Epoch 3/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.4181 - accuracy: 0.7958
# Epoch 4/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.4111 - accuracy: 0.7987
# Epoch 5/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.4077 - accuracy: 0.7980
# Epoch 6/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.4047 - accuracy: 0.7984
# Epoch 7/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4034 - accuracy: 0.7971
# Epoch 8/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4019 - accuracy: 0.7970
# Epoch 9/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4012 - accuracy: 0.7991
# Epoch 10/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4005 - accuracy: 0.7978
# Epoch 11/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3997 - accuracy: 0.7987
# Epoch 12/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3986 - accuracy: 0.7988
# Epoch 13/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3984 - accuracy: 0.7999
# Epoch 14/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3979 - accuracy: 0.7987
# Epoch 15/50
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3974 - accuracy: 0.7993
# Epoch 16/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3971 - accuracy: 0.7994
# Epoch 17/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3962 - accuracy: 0.7983
# Epoch 18/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3953 - accuracy: 0.8009
# Epoch 19/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3949 - accuracy: 0.8009
# Epoch 20/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3949 - accuracy: 0.7993
# Epoch 21/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3944 - accuracy: 0.8021
# Epoch 22/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3942 - accuracy: 0.7994
# Epoch 23/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3940 - accuracy: 0.8012
# Epoch 24/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3936 - accuracy: 0.8009
# Epoch 25/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3934 - accuracy: 0.8019
# Epoch 26/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3934 - accuracy: 0.8004
# Epoch 27/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3930 - accuracy: 0.8024
# Epoch 28/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3933 - accuracy: 0.8007
# Epoch 29/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3926 - accuracy: 0.8034
# Epoch 30/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3925 - accuracy: 0.8027
# Epoch 31/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3924 - accuracy: 0.8021
# Epoch 32/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3925 - accuracy: 0.8041
# Epoch 33/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3923 - accuracy: 0.8035
# Epoch 34/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3919 - accuracy: 0.8024
# Epoch 35/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3920 - accuracy: 0.8054
# Epoch 36/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3920 - accuracy: 0.8020
# Epoch 37/50
# 2723/2723 [==============================] - 9s 3ms/step - loss: 0.3909 - accuracy: 0.8020
# Epoch 38/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3914 - accuracy: 0.8045
# Epoch 39/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3910 - accuracy: 0.8028
# Epoch 40/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3910 - accuracy: 0.8035
# Epoch 41/50
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3915 - accuracy: 0.8038
# Epoch 42/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3906 - accuracy: 0.8030
# Epoch 43/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3908 - accuracy: 0.8035
# Epoch 44/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3907 - accuracy: 0.8044
# Epoch 45/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3906 - accuracy: 0.8037
# Epoch 46/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3905 - accuracy: 0.8038
# Epoch 47/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3904 - accuracy: 0.8018
# Epoch 48/50
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3905 - accuracy: 0.8035
# Epoch 49/50
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3905 - accuracy: 0.8036
# Epoch 50/50
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3905 - accuracy: 0.8050
# 213/213 [==============================] - 0s 2ms/step
#
# Attempt # 7
# Accuracy:  0.8091389950044079
# Confusion Matrix:
#  [[2629  767]
#  [ 532 2878]]
# Precision:  0.7895747599451303
# Recall:  0.8439882697947214
# F1 Score:  0.8158752657689582

# %% [markdown]
# ## Attempt# 08

# %%
first_dense = 25
second_dense = 6

model = get_model_initialization(first_dense, second_dense)

# Train the model
model.fit(X_train, y_train, epochs=200, batch_size=10)

get_Model_score(X_test, y_test, 8)
# Out:
# Epoch 1/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.5205 - accuracy: 0.7712
# Epoch 2/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4434 - accuracy: 0.7870
# Epoch 3/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4224 - accuracy: 0.7925
# Epoch 4/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4128 - accuracy: 0.7963
# Epoch 5/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4071 - accuracy: 0.7999
# Epoch 6/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4045 - accuracy: 0.7983
# Epoch 7/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4020 - accuracy: 0.8005
# Epoch 8/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4007 - accuracy: 0.7992
# Epoch 9/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3995 - accuracy: 0.8004
# Epoch 10/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3986 - accuracy: 0.8024
# Epoch 11/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3978 - accuracy: 0.8003
# Epoch 12/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3965 - accuracy: 0.8042
# Epoch 13/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3964 - accuracy: 0.8044
# Epoch 14/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3956 - accuracy: 0.8016
# Epoch 15/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3948 - accuracy: 0.8033
# Epoch 16/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3948 - accuracy: 0.8038
# Epoch 17/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3939 - accuracy: 0.8037
# Epoch 18/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3939 - accuracy: 0.8055
# Epoch 19/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3934 - accuracy: 0.8060
# Epoch 20/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3930 - accuracy: 0.8039
# Epoch 21/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3928 - accuracy: 0.8071
# Epoch 22/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3929 - accuracy: 0.8052
# Epoch 23/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3928 - accuracy: 0.8039
# Epoch 24/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3923 - accuracy: 0.8033
# Epoch 25/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3918 - accuracy: 0.8051
# Epoch 26/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3916 - accuracy: 0.8051
# Epoch 27/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3912 - accuracy: 0.8044
# Epoch 28/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3912 - accuracy: 0.8050
# Epoch 29/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3909 - accuracy: 0.8037
# Epoch 30/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3906 - accuracy: 0.8037
# Epoch 31/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3901 - accuracy: 0.8056
# Epoch 32/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3906 - accuracy: 0.8048
# Epoch 33/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3901 - accuracy: 0.8051
# Epoch 34/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3897 - accuracy: 0.8045
# Epoch 35/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3899 - accuracy: 0.8058
# Epoch 36/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3901 - accuracy: 0.8059
# Epoch 37/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3895 - accuracy: 0.8055
# Epoch 38/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3895 - accuracy: 0.8073
# Epoch 39/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3896 - accuracy: 0.8032
# Epoch 40/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3894 - accuracy: 0.8063
# Epoch 41/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3892 - accuracy: 0.8055
# Epoch 42/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3894 - accuracy: 0.8040
# Epoch 43/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3890 - accuracy: 0.8067
# Epoch 44/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3890 - accuracy: 0.8074
# Epoch 45/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3894 - accuracy: 0.8055
# Epoch 46/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3896 - accuracy: 0.8059
# Epoch 47/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3887 - accuracy: 0.8030
# Epoch 48/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3886 - accuracy: 0.8051
# Epoch 49/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3887 - accuracy: 0.8059
# Epoch 50/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3883 - accuracy: 0.8060
# Epoch 51/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3884 - accuracy: 0.8055
# Epoch 52/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3888 - accuracy: 0.8046
# Epoch 53/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3884 - accuracy: 0.8049
# Epoch 54/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3881 - accuracy: 0.8050
# Epoch 55/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3882 - accuracy: 0.8061
# Epoch 56/200
# 2723/2723 [==============================] - 9s 3ms/step - loss: 0.3883 - accuracy: 0.8066
# Epoch 57/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3881 - accuracy: 0.8055
# Epoch 58/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3879 - accuracy: 0.8074
# Epoch 59/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3875 - accuracy: 0.8059
# Epoch 60/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3879 - accuracy: 0.8049
# Epoch 61/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3875 - accuracy: 0.8058
# Epoch 62/200
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.3874 - accuracy: 0.8065
# Epoch 63/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3879 - accuracy: 0.8065
# Epoch 64/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3878 - accuracy: 0.8051
# Epoch 65/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3877 - accuracy: 0.8052
# Epoch 66/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3873 - accuracy: 0.8071
# Epoch 67/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3876 - accuracy: 0.8063
# Epoch 68/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3873 - accuracy: 0.8046
# Epoch 69/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3871 - accuracy: 0.8062
# Epoch 70/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3874 - accuracy: 0.8052
# Epoch 71/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3877 - accuracy: 0.8066
# Epoch 72/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3874 - accuracy: 0.8063
# Epoch 73/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3872 - accuracy: 0.8058
# Epoch 74/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3874 - accuracy: 0.8054
# Epoch 75/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3872 - accuracy: 0.8070
# Epoch 76/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3873 - accuracy: 0.8064
# Epoch 77/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3872 - accuracy: 0.8054
# Epoch 78/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3870 - accuracy: 0.8054
# Epoch 79/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3867 - accuracy: 0.8064
# Epoch 80/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3871 - accuracy: 0.8071
# Epoch 81/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3871 - accuracy: 0.8058
# Epoch 82/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3866 - accuracy: 0.8072
# Epoch 83/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3870 - accuracy: 0.8052
# Epoch 84/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3866 - accuracy: 0.8056
# Epoch 85/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3865 - accuracy: 0.8065
# Epoch 86/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3868 - accuracy: 0.8066
# Epoch 87/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3868 - accuracy: 0.8049
# Epoch 88/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3868 - accuracy: 0.8060
# Epoch 89/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3865 - accuracy: 0.8070
# Epoch 90/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3868 - accuracy: 0.8071
# Epoch 91/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3864 - accuracy: 0.8067
# Epoch 92/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3867 - accuracy: 0.8058
# Epoch 93/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3866 - accuracy: 0.8068
# Epoch 94/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3866 - accuracy: 0.8058
# Epoch 95/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3869 - accuracy: 0.8055
# Epoch 96/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3861 - accuracy: 0.8070
# Epoch 97/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3862 - accuracy: 0.8059
# Epoch 98/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3863 - accuracy: 0.8067
# Epoch 99/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3864 - accuracy: 0.8070
# Epoch 100/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3862 - accuracy: 0.8071
# Epoch 101/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3863 - accuracy: 0.8085
# Epoch 102/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3857 - accuracy: 0.8059
# Epoch 103/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3860 - accuracy: 0.8079
# Epoch 104/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3859 - accuracy: 0.8051
# Epoch 105/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3861 - accuracy: 0.8070
# Epoch 106/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3865 - accuracy: 0.8066
# Epoch 107/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3863 - accuracy: 0.8061
# Epoch 108/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3861 - accuracy: 0.8056
# Epoch 109/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3862 - accuracy: 0.8073
# Epoch 110/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3861 - accuracy: 0.8071
# Epoch 111/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3860 - accuracy: 0.8075
# Epoch 112/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3862 - accuracy: 0.8056
# Epoch 113/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3860 - accuracy: 0.8063
# Epoch 114/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3860 - accuracy: 0.8091
# Epoch 115/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3861 - accuracy: 0.8072
# Epoch 116/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3862 - accuracy: 0.8076
# Epoch 117/200
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.3859 - accuracy: 0.8077
# Epoch 118/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3861 - accuracy: 0.8057
# Epoch 119/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3862 - accuracy: 0.8075
# Epoch 120/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3863 - accuracy: 0.8076
# Epoch 121/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3861 - accuracy: 0.8078
# Epoch 122/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3858 - accuracy: 0.8099
# Epoch 123/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3859 - accuracy: 0.8071
# Epoch 124/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3860 - accuracy: 0.8066
# Epoch 125/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3858 - accuracy: 0.8076
# Epoch 126/200
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3860 - accuracy: 0.8075
# Epoch 127/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3859 - accuracy: 0.8073
# Epoch 128/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3853 - accuracy: 0.8078
# Epoch 129/200
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3855 - accuracy: 0.8071
# Epoch 130/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3857 - accuracy: 0.8049
# Epoch 131/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3858 - accuracy: 0.8057
# Epoch 132/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3856 - accuracy: 0.8068
# Epoch 133/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3856 - accuracy: 0.8094
# Epoch 134/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3856 - accuracy: 0.8068
# Epoch 135/200
# 2723/2723 [==============================] - 9s 3ms/step - loss: 0.3856 - accuracy: 0.8072
# Epoch 136/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3854 - accuracy: 0.8039
# Epoch 137/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3858 - accuracy: 0.8055
# Epoch 138/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3855 - accuracy: 0.8074
# Epoch 139/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3860 - accuracy: 0.8075
# Epoch 140/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3858 - accuracy: 0.8056
# Epoch 141/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3856 - accuracy: 0.8067
# Epoch 142/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3852 - accuracy: 0.8086
# Epoch 143/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3856 - accuracy: 0.8072
# Epoch 144/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3857 - accuracy: 0.8074
# Epoch 145/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3855 - accuracy: 0.8068
# Epoch 146/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3852 - accuracy: 0.8069
# Epoch 147/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3857 - accuracy: 0.8080
# Epoch 148/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3855 - accuracy: 0.8068
# Epoch 149/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3854 - accuracy: 0.8085
# Epoch 150/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3854 - accuracy: 0.8060
# Epoch 151/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3854 - accuracy: 0.8077
# Epoch 152/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3856 - accuracy: 0.8058
# Epoch 153/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3851 - accuracy: 0.8066
# Epoch 154/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3852 - accuracy: 0.8083
# Epoch 155/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3855 - accuracy: 0.8069
# Epoch 156/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3852 - accuracy: 0.8068
# Epoch 157/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3852 - accuracy: 0.8086
# Epoch 158/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3852 - accuracy: 0.8073
# Epoch 159/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3854 - accuracy: 0.8063
# Epoch 160/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3851 - accuracy: 0.8074
# Epoch 161/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3852 - accuracy: 0.8068
# Epoch 162/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3857 - accuracy: 0.8052
# Epoch 163/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3853 - accuracy: 0.8067
# Epoch 164/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3853 - accuracy: 0.8059
# Epoch 165/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3848 - accuracy: 0.8079
# Epoch 166/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3857 - accuracy: 0.8080
# Epoch 167/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3851 - accuracy: 0.8079
# Epoch 168/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3854 - accuracy: 0.8059
# Epoch 169/200
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.3849 - accuracy: 0.8072
# Epoch 170/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3854 - accuracy: 0.8071
# Epoch 171/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3853 - accuracy: 0.8051
# Epoch 172/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3853 - accuracy: 0.8071
# Epoch 173/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3853 - accuracy: 0.8073
# Epoch 174/200
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.3853 - accuracy: 0.8067
# Epoch 175/200
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.3850 - accuracy: 0.8075
# Epoch 176/200
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.3853 - accuracy: 0.8066
# Epoch 177/200
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.3852 - accuracy: 0.8064
# Epoch 178/200
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.3851 - accuracy: 0.8074
# Epoch 179/200
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3853 - accuracy: 0.8064
# Epoch 180/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3852 - accuracy: 0.8048
# Epoch 181/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3850 - accuracy: 0.8083
# Epoch 182/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3852 - accuracy: 0.8081
# Epoch 183/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3852 - accuracy: 0.8076
# Epoch 184/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3852 - accuracy: 0.8066
# Epoch 185/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3850 - accuracy: 0.8064
# Epoch 186/200
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.3850 - accuracy: 0.8056
# Epoch 187/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3847 - accuracy: 0.8086
# Epoch 188/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3850 - accuracy: 0.8052
# Epoch 189/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3853 - accuracy: 0.8083
# Epoch 190/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3851 - accuracy: 0.8068
# Epoch 191/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3852 - accuracy: 0.8059
# Epoch 192/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3850 - accuracy: 0.8090
# Epoch 193/200
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3848 - accuracy: 0.8067
# Epoch 194/200
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3845 - accuracy: 0.8082
# Epoch 195/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3851 - accuracy: 0.8079
# Epoch 196/200
# 2723/2723 [==============================] - 5s 2ms/step - loss: 0.3844 - accuracy: 0.8067
# Epoch 197/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3854 - accuracy: 0.8068
# Epoch 198/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3850 - accuracy: 0.8088
# Epoch 199/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3852 - accuracy: 0.8071
# Epoch 200/200
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3852 - accuracy: 0.8089
# 213/213 [==============================] - 0s 2ms/step
#
# Attempt # 8
# Accuracy:  0.8107552159858948
# Confusion Matrix:
#  [[2636  760]
#  [ 528 2882]]
# Precision:  0.7913234486545854
# Recall:  0.8451612903225807
# F1 Score:  0.817356778218945

# %% [markdown]
# ## Attempt# 09

# %%
first_dense = 30
second_dense = 6

model = get_model_initialization(first_dense, second_dense)

# Train the model
model.fit(X_train, y_train, epochs=300, batch_size=10)

get_Model_score(X_test, y_test, 9)
# Out:
# Epoch 1/300
# 2723/2723 [==============================] - 8s 3ms/step - loss: 0.4724 - accuracy: 0.7756
# Epoch 2/300
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.4234 - accuracy: 0.7931
# Epoch 3/300
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4118 - accuracy: 0.7940
# Epoch 4/300
# 2723/2723 [==============================] - 7s 2ms/step - loss: 0.4060 - accuracy: 0.7963
# Epoch 5/300
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.4018 - accuracy: 0.7987
# Epoch 6/300
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3991 - accuracy: 0.7998
# Epoch 7/300
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3976 - accuracy: 0.8000
# Epoch 8/300
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3965 - accuracy: 0.7989
# Epoch 9/300
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3956 - accuracy: 0.8001
# Epoch 10/300
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3955 - accuracy: 0.8005
# Epoch 11/300
# 2723/2723 [==============================] - 6s 2ms/step - loss: 0.3944 - accuracy: 0.8008
# Epoch 12/300
# 2723/2723 [==============================] - 7s 3ms/step - loss: 0.3936 - accuracy: 0.8023
# Epoch 13/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3927 - accuracy: 0.8024
# Epoch 14/300
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3924 - accuracy: 0.8027
# Epoch 15/300
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3922 - accuracy: 0.8038
# Epoch 16/300
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3919 - accuracy: 0.8037
# Epoch 17/300
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3917 - accuracy: 0.8032
# Epoch 18/300
# 2723/2723 [==============================] - 19s 7ms/step - loss: 0.3911 - accuracy: 0.8041
# Epoch 19/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3909 - accuracy: 0.8045
# Epoch 20/300
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3912 - accuracy: 0.8043
# Epoch 21/300
# 2723/2723 [==============================] - 15s 5ms/step - loss: 0.3903 - accuracy: 0.8044
# Epoch 22/300
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3905 - accuracy: 0.8034
# Epoch 23/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3896 - accuracy: 0.8022
# Epoch 24/300
# 2723/2723 [==============================] - 16s 6ms/step - loss: 0.3901 - accuracy: 0.8039
# Epoch 25/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3897 - accuracy: 0.8029
# Epoch 26/300
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3899 - accuracy: 0.8037
# Epoch 27/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3897 - accuracy: 0.8040
# Epoch 28/300
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3885 - accuracy: 0.8044
# Epoch 29/300
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3893 - accuracy: 0.8053
# Epoch 30/300
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3884 - accuracy: 0.8039
# Epoch 31/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3887 - accuracy: 0.8056
# Epoch 32/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3889 - accuracy: 0.8052
# Epoch 33/300
# 2723/2723 [==============================] - 14s 5ms/step - loss: 0.3884 - accuracy: 0.8046
# Epoch 34/300
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3884 - accuracy: 0.8042
# Epoch 35/300
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3881 - accuracy: 0.8074
# Epoch 36/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3882 - accuracy: 0.8064
# Epoch 37/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3881 - accuracy: 0.8047
# Epoch 38/300
# 2723/2723 [==============================] - 11s 4ms/step - loss: 0.3878 - accuracy: 0.8050
# Epoch 39/300
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3878 - accuracy: 0.8058
# Epoch 40/300
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3873 - accuracy: 0.8055
# Epoch 41/300
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3879 - accuracy: 0.8058
# Epoch 42/300
# 2723/2723 [==============================] - 12s 4ms/step - loss: 0.3875 - accuracy: 0.8048
# Epoch 43/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3878 - accuracy: 0.8059
# Epoch 44/300
# 2723/2723 [==============================] - 12s 5ms/step - loss: 0.3876 - accuracy: 0.8045
# Epoch 45/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3872 - accuracy: 0.8074
# Epoch 46/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3871 - accuracy: 0.8071
# Epoch 47/300
# 2723/2723 [==============================] - 13s 5ms/step - loss: 0.3873 - accuracy: 0.8071
# Epoch 48/300
# 2474/2723 [==========================>...] - ETA: 1s - loss: 0.3875 - accuracy: 0.8064

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the model
model = LogisticRegression()

# Train the model
model.fit(X_train, y_train)

# Evaluate the model
score = model.score(X_test, y_test)
print("Accuracy: {:.2f}%".format(score * 100))
print()

get_Model_score(X_test, y_test, 1)
# Out:
# Accuracy: 76.77%
#
#
# Attempt # 1
# Accuracy:  0.7677049662062886
# Confusion Matrix:
#  [[2840  556]
#  [1025 2385]]
# Precision:  0.8109486569194152
# Recall:  0.6994134897360704
# F1 Score:  0.7510628247520076

# %% [markdown]
# # Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize the model
model = DecisionTreeClassifier()

# Train the model
model.fit(X_train, y_train)

# Evaluate the model
score = model.score(X_test, y_test)
print("Accuracy: {:.2f}%".format(score * 100))
print()

get_Model_score(X_test, y_test, 1)
# Out:
# Accuracy: 80.87%
#
#
# Attempt # 1
# Accuracy:  0.8086982074640023
# Confusion Matrix:
#  [[2620  776]
#  [ 526 2884]]
# Precision:  0.7879781420765027
# Recall:  0.8457478005865102
# F1 Score:  0.8158415841584158

# %% [markdown]
# # Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize the model
model = RandomForestClassifier(n_estimators=100)

# Train the model
model.fit(X_train, y_train)

# Evaluate the model
score = model.score(X_test, y_test)
print("Accuracy: {:.2f}%".format(score * 100))
print()

get_Model_score(X_test, y_test, 1)
# Out:
# Accuracy: 80.93%
#
#
# Attempt # 1
# Accuracy:  0.809285924184543
# Confusion Matrix:
#  [[2616  780]
#  [ 518 2892]]
# Precision:  0.7875816993464052
# Recall:  0.8480938416422288
# F1 Score:  0.8167184411183283

# %% [markdown]
# # Support Vector Machines (SVMs)

# %%
from sklearn.svm import SVC

# Initialize the model
model = SVC()

# Train the model
model.fit(X_train, y_train)

# Evaluate the model
score = model.score(X_test, y_test)
print("Accuracy: {:.2f}%".format(score * 100))
print()

get_Model_score(X_test, y_test, 1)
# Out:
# Accuracy: 81.05%
#
#
# Attempt # 1
# Accuracy:  0.8104613576256244
# Confusion Matrix:
#  [[2644  752]
#  [ 538 2872]]
# Precision:  0.7924944812362031
# Recall:  0.8422287390029326
# F1 Score:  0.8166050611316463

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

Adab = AdaBoostClassifier(DecisionTreeClassifier(), n_estimators = 5)
Adab.fit(X_train, y_train)

print("score for training dataset:",Adab.score(X_train, y_train))
print("score for test dataset:",Adab.score(X_test, y_test))
print("predict:",Adab.predict(X_test))

print()

# get_Model_score(X_test, y_test, 1)
# Out:
# score for training dataset: 0.8091249724487547
# score for test dataset: 0.8091389950044079
# predict: [0 0 0 ... 0 0 1]

# %%
# Predict the target values for the test data
y_pred = Adab.predict(X_test)

# Convert the predicted probabilities to binary labels
y_pred = [1 if y>0.5 else 0 for y in y_pred]

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

print("Accuracy: ", accuracy)
print("Confusion Matrix: \n", cm)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
# Out:
# Accuracy:  0.8091389950044079
# Confusion Matrix:
#  [[2615  781]
#  [ 518 2892]]
# Precision:  0.7873672747073237
# Recall:  0.8480938416422288
# F1 Score:  0.8166031342651419
