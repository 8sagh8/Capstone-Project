# %% [markdown]
# # Import Libraries & Packages

# %%
import pandas as pd
import numpy as np

# %%
# import data from newly created file
df = pd.read_csv("./newFile.csv")

# dataframe shape
df.shape
# Out:
# (17880, 18)

# %%
# display top 2 entries fo dataframe
df.head(2)
# Out:
#                                        title salary_range  \
# 0                           Marketing Intern          NaN
# 1  Customer Service - Cloud Video Production          NaN
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
#
#                                             benefits  telecommuting  \
# 0                                                NaN              0
# 1  What you will get from usThrough being part of...              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
#
#   required_education                   industry          function  fraudulent  \
# 0                NaN                        NaN         Marketing           0
# 1                NaN  Marketing and Advertising  Customer Service           0
#
#   Country State       City  has_company_profile
# 0      US    NY   New York                    1
# 1      NZ         Auckland                    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                17880 non-null  object
#  1   salary_range         2868 non-null   object
#  2   description          17879 non-null  object
#  3   requirements         15185 non-null  object
#  4   benefits             10670 non-null  object
#  5   telecommuting        17880 non-null  int64
#  6   has_company_logo     17880 non-null  int64
#  7   has_questions        17880 non-null  int64
#  8   employment_type      14409 non-null  object
#  9   required_experience  10830 non-null  object
#  10  required_education   9775 non-null   object
#  11  industry             12977 non-null  object
#  12  function             17880 non-null  object
#  13  fraudulent           17880 non-null  int64
#  14  Country              17534 non-null  object
#  15  State                17440 non-null  object
#  16  City                 17440 non-null  object
#  17  has_company_profile  17880 non-null  int64
# dtypes: int64(5), object(13)
# memory usage: 2.5+ MB

# %% [markdown]
# # Encoding - Label Encoding

# %%
# Label Encoding

# Select the columns to encode
columns_to_encode = ['Country', 'State', 'City', 'function']

# Perform label encoding
df[columns_to_encode] = df[columns_to_encode].apply(lambda col: col.astype('category').cat.codes)

# Show the encoded dataset
df
# Out:
#                                                    title salary_range  \
# 0                                       Marketing Intern          NaN
# 1              Customer Service - Cloud Video Production          NaN
# 2                Commissioning Machinery Assistant (CMA)          NaN
# 3                      Account Executive - Washington DC          NaN
# 4                                    Bill Review Manager          NaN
# ...                                                  ...          ...
# 17875                   Account Director - Distribution           NaN
# 17876                                 Payroll Accountant          NaN
# 17877  Project Cost Control Staff Engineer - Cost Con...          NaN
# 17878                                   Graphic Designer          NaN
# 17879                         Web Application Developers          NaN
#
#                                              description  \
# 0      Food52, a fast-growing, James Beard Award-winn...
# 1      Organised - Focused - Vibrant - Awesome!Do you...
# 2      Our client, located in Houston, is actively se...
# 3      THE COMPANY: ESRI – Environmental Systems Rese...
# 4      JOB TITLE: Itemization Review ManagerLOCATION:...
# ...                                                  ...
# 17875  Just in case this is the first time you’ve vis...
# 17876  The Payroll Accountant will focus primarily on...
# 17877  Experienced Project Cost Control Staff Enginee...
# 17878  Nemsia Studios is looking for an experienced v...
# 17879  Who are we?Vend is an award winning web based ...
#
#                                             requirements  \
# 0      Experience with content management systems a m...
# 1      What we expect from you:Your key responsibilit...
# 2      Implement pre-commissioning and commissioning ...
# 3      EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4      QUALIFICATIONS:RN license in the State of Texa...
# ...                                                  ...
# 17875  To ace this role you:Will eat comprehensive St...
# 17876  - B.A. or B.S. in Accounting- Desire to have f...
# 17877  At least 12 years professional experience.Abil...
# 17878  1. Must be fluent in the latest versions of Co...
# 17879  We want to hear from you if:You have an in-dep...
#
#                                                 benefits  telecommuting  \
# 0                                                    NaN              0
# 1      What you will get from usThrough being part of...              0
# 2                                                    NaN              0
# 3      Our culture is anything but corporate—we have ...              0
# 4                                  Full Benefits Offered              0
# ...                                                  ...            ...
# 17875  What can you expect from us?We have an open cu...              0
# 17876  Health &amp; WellnessMedical planPrescription ...              0
# 17877                                                NaN              0
# 17878  Competitive salary (compensation will be based...              0
# 17879                                                NaN              0
#
#        has_company_logo  has_questions employment_type required_experience  \
# 0                     1              0           Other          Internship
# 1                     1              0       Full-time      Not Applicable
# 2                     1              0             NaN                 NaN
# 3                     1              0       Full-time    Mid-Senior level
# 4                     1              1       Full-time    Mid-Senior level
# ...                 ...            ...             ...                 ...
# 17875                 1              1       Full-time    Mid-Senior level
# 17876                 1              1       Full-time    Mid-Senior level
# 17877                 0              0       Full-time                 NaN
# 17878                 0              1        Contract      Not Applicable
# 17879                 1              1       Full-time    Mid-Senior level
#
#       required_education                   industry  function  fraudulent  \
# 0                    NaN                        NaN       139           0
# 1                    NaN  Marketing and Advertising        59           0
# 2                    NaN                        NaN       159           0
# 3      Bachelor's Degree          Computer Software       195           0
# 4      Bachelor's Degree     Hospital & Health Care       104           0
# ...                  ...                        ...       ...         ...
# 17875                NaN          Computer Software       195           0
# 17876  Bachelor's Degree                   Internet         1           0
# 17877                NaN                        NaN       300           0
# 17878       Professional             Graphic Design        67           0
# 17879                NaN          Computer Software        79           0
#
#        Country  State  City  has_company_profile
# 0           85    187  1399                    1
# 1           60      0   160                    1
# 2           85    115  2136                    1
# 3           85     64  2089                    1
# 4           85     90   742                    1
# ...        ...    ...   ...                  ...
# 17875       12    194  2007                    1
# 17876       85    198  1568                    1
# 17877       85    248   928                    1
# 17878       56    135  1065                    0
# 17879       60    164  2105                    1
#
# [17880 rows x 18 columns]

# %% [markdown]
# # Create DataSet for training purpose

# %%
train_data = df[['Country', 'State', 'City', 'has_company_profile', 'function']]
label = df['fraudulent']

# %% [markdown]
# ### Data split

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(train_data, label, test_size=0.3, random_state=42)

# %%
# Building SVM model

# %%
from sklearn import svm
from sklearn import metrics

# %%
# getting 20% of training set to check it for testing purpose
xx_train, xx_test, yy_train, yy_test = train_test_split(train_data_2, label, test_size=0.8, random_state=42)

# %%
# Create the SVM model
clf = svm.SVC(kernel='linear')

# %%
# Train the model
clf.fit(xx_train, yy_train)

# %%
# Make predictions on the testing data
y_pred = clf.predict(X_test)

# %%
# Evaluate the model's performance
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))

# %% [markdown]
# # Building Neural Network Model

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialize model
model = Sequential()

# Add first layer with input dimension of 3 (number of features)
model.add(Dense(10, input_dim=5, activation='relu'))

# Add second layer
model.add(Dense(8, activation='relu'))

# Add output layer with sigmoid activation function
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 1.8492 - accuracy: 0.9041
# Epoch 2/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.5082 - accuracy: 0.9283
# Epoch 3/100
# 1252/1252 [==============================] - 2s 1ms/step - loss: 0.3851 - accuracy: 0.9374
# Epoch 4/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.4023 - accuracy: 0.9360
# Epoch 5/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.3631 - accuracy: 0.9366
# Epoch 6/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.3247 - accuracy: 0.9401
# Epoch 7/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.3566 - accuracy: 0.9386
# Epoch 8/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.3267 - accuracy: 0.9397
# Epoch 9/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.3641 - accuracy: 0.9368
# Epoch 10/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.3225 - accuracy: 0.9358
# Epoch 11/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.3120 - accuracy: 0.9393
# Epoch 12/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.3695 - accuracy: 0.9338
# Epoch 13/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.3517 - accuracy: 0.9364
# Epoch 14/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2741 - accuracy: 0.9430
# Epoch 15/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.3193 - accuracy: 0.9369
# Epoch 16/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.3043 - accuracy: 0.9408
# Epoch 17/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2664 - accuracy: 0.9398
# Epoch 18/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.3198 - accuracy: 0.9390
# Epoch 19/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.3039 - accuracy: 0.9398
# Epoch 20/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2999 - accuracy: 0.9386
# Epoch 21/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2778 - accuracy: 0.9396
# Epoch 22/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.2651 - accuracy: 0.9401
# Epoch 23/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2780 - accuracy: 0.9411
# Epoch 24/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2733 - accuracy: 0.9416
# Epoch 25/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.2607 - accuracy: 0.9437
# Epoch 26/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2351 - accuracy: 0.9450
# Epoch 27/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2392 - accuracy: 0.9447
# Epoch 28/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2201 - accuracy: 0.9442
# Epoch 29/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.2522 - accuracy: 0.9451
# Epoch 30/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2378 - accuracy: 0.9442
# Epoch 31/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2231 - accuracy: 0.9480
# Epoch 32/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.2187 - accuracy: 0.9466
# Epoch 33/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.2029 - accuracy: 0.9485
# Epoch 34/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1805 - accuracy: 0.9515
# Epoch 35/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1965 - accuracy: 0.9501
# Epoch 36/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1930 - accuracy: 0.9488
# Epoch 37/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1751 - accuracy: 0.9526
# Epoch 38/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1837 - accuracy: 0.9509
# Epoch 39/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1682 - accuracy: 0.9529
# Epoch 40/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1700 - accuracy: 0.9507
# Epoch 41/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1732 - accuracy: 0.9511
# Epoch 42/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1688 - accuracy: 0.9519
# Epoch 43/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1672 - accuracy: 0.9517
# Epoch 44/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1690 - accuracy: 0.9518
# Epoch 45/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1652 - accuracy: 0.9524
# Epoch 46/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1594 - accuracy: 0.9521
# Epoch 47/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1594 - accuracy: 0.9524
# Epoch 48/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1613 - accuracy: 0.9513
# Epoch 49/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1571 - accuracy: 0.9535
# Epoch 50/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1580 - accuracy: 0.9526
# Epoch 51/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1559 - accuracy: 0.9526
# Epoch 52/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1560 - accuracy: 0.9525
# Epoch 53/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1570 - accuracy: 0.9529
# Epoch 54/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1577 - accuracy: 0.9520
# Epoch 55/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1550 - accuracy: 0.9537
# Epoch 56/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1528 - accuracy: 0.9543
# Epoch 57/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1511 - accuracy: 0.9538
# Epoch 58/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1541 - accuracy: 0.9548
# Epoch 59/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1526 - accuracy: 0.9552
# Epoch 60/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1521 - accuracy: 0.9537
# Epoch 61/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1541 - accuracy: 0.9543
# Epoch 62/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1501 - accuracy: 0.9544
# Epoch 63/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1508 - accuracy: 0.9538
# Epoch 64/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1507 - accuracy: 0.9550
# Epoch 65/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1490 - accuracy: 0.9550
# Epoch 66/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1489 - accuracy: 0.9542
# Epoch 67/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1502 - accuracy: 0.9555
# Epoch 68/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1478 - accuracy: 0.9546
# Epoch 69/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1471 - accuracy: 0.9554
# Epoch 70/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1483 - accuracy: 0.9549
# Epoch 71/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1458 - accuracy: 0.9553
# Epoch 72/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1483 - accuracy: 0.9557
# Epoch 73/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1467 - accuracy: 0.9541
# Epoch 74/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1480 - accuracy: 0.9542
# Epoch 75/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1471 - accuracy: 0.9542
# Epoch 76/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1482 - accuracy: 0.9547
# Epoch 77/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1471 - accuracy: 0.9555
# Epoch 78/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1462 - accuracy: 0.9552
# Epoch 79/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1452 - accuracy: 0.9564
# Epoch 80/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1458 - accuracy: 0.9550
# Epoch 81/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1470 - accuracy: 0.9549
# Epoch 82/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1457 - accuracy: 0.9547
# Epoch 83/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1467 - accuracy: 0.9541
# Epoch 84/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1463 - accuracy: 0.9559
# Epoch 85/100
# 1252/1252 [==============================] - 3s 3ms/step - loss: 0.1465 - accuracy: 0.9542
# Epoch 86/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1451 - accuracy: 0.9556
# Epoch 87/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1443 - accuracy: 0.9537
# Epoch 88/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1462 - accuracy: 0.9544
# Epoch 89/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1438 - accuracy: 0.9557
# Epoch 90/100
# 1252/1252 [==============================] - 3s 3ms/step - loss: 0.1447 - accuracy: 0.9556
# Epoch 91/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1443 - accuracy: 0.9548
# Epoch 92/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1458 - accuracy: 0.9556
# Epoch 93/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1421 - accuracy: 0.9543
# Epoch 94/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1449 - accuracy: 0.9544
# Epoch 95/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1465 - accuracy: 0.9546
# Epoch 96/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1429 - accuracy: 0.9554
# Epoch 97/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1439 - accuracy: 0.9540
# Epoch 98/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1453 - accuracy: 0.9555
# Epoch 99/100
# 1252/1252 [==============================] - 2s 2ms/step - loss: 0.1445 - accuracy: 0.9555
# Epoch 100/100
# 1252/1252 [==============================] - 3s 2ms/step - loss: 0.1432 - accuracy: 0.9555

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# Predict the target values for the test data
y_pred = model.predict(X_test)

# Convert the predicted probabilities to binary labels
y_pred = [1 if y>0.5 else 0 for y in y_pred]

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Calculate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate precision
precision = precision_score(y_test, y_pred)

# Calculate recall
recall = recall_score(y_test, y_pred)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

print("Accuracy: ", accuracy)
print("Confusion Matrix: \n", cm)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
# Out:
# 168/168 [==============================] - 0s 1ms/step
# Accuracy:  0.9511558538404176
# Confusion Matrix:
#  [[5062   31]
#  [ 231   40]]
# Precision:  0.5633802816901409
# Recall:  0.14760147601476015
# F1 Score:  0.23391812865497075
