# %%
# Loading neccesary libraries:

import random
import numpy as np
import pandas as pd

# %%
# To print multiple outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Import dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15280/3890063786.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
#Reading the data from google drive
# data=pd.read_csv('/content/gdrive/MyDrive/Dataset_CapstoneProject/newFile.csv')
df = pd.read_csv('./newFile.csv')
#Print that data imported successfully
print("Data imported successfully")
# Out:
# Data imported successfully

# %% [markdown]
# # View top 10 rows of dataset

# %%
#Write your code here
df.head(10)
# Out:
#                                        title salary_range  \
# 0                           Marketing Intern          NaN
# 1  Customer Service - Cloud Video Production          NaN
# 2    Commissioning Machinery Assistant (CMA)          NaN
# 3          Account Executive - Washington DC          NaN
# 4                        Bill Review Manager          NaN
# 5                           Accounting Clerk          NaN
# 6                      Head of Content (m/f)  20000-28000
# 7           Lead Guest Service Specialist             NaN
# 8                                 HP BSM SME          NaN
# 9    Customer Service Associate - Part Time           NaN
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI – Environmental Systems Rese...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
# ...

# %%
df.describe()
# Out:
#        telecommuting  has_company_logo  has_questions    fraudulent  \
# count   17880.000000      17880.000000   17880.000000  17880.000000
# mean        0.042897          0.795302       0.491723      0.048434
# std         0.202631          0.403492       0.499945      0.214688
# min         0.000000          0.000000       0.000000      0.000000
# 25%         0.000000          1.000000       0.000000      0.000000
# 50%         0.000000          1.000000       0.000000      0.000000
# 75%         0.000000          1.000000       1.000000      0.000000
# max         1.000000          1.000000       1.000000      1.000000
#
#        has_company_profile
# count         17880.000000
# mean              0.814989
# std               0.388317
# min               0.000000
# 25%               1.000000
# 50%               1.000000
# 75%               1.000000
# max               1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                17880 non-null  object
#  1   salary_range         2868 non-null   object
#  2   description          17879 non-null  object
#  3   requirements         15185 non-null  object
#  4   benefits             10670 non-null  object
#  5   telecommuting        17880 non-null  int64
#  6   has_company_logo     17880 non-null  int64
#  7   has_questions        17880 non-null  int64
#  8   employment_type      14409 non-null  object
#  9   required_experience  10830 non-null  object
#  10  required_education   9775 non-null   object
#  11  industry             12977 non-null  object
#  12  function             17880 non-null  object
#  13  fraudulent           17880 non-null  int64
#  14  Country              17534 non-null  object
# ...

# %%
df.isnull ().sum ()
# Out:
# title                      0
# salary_range           15012
# description                1
# requirements            2695
# benefits                7210
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                   0
# fraudulent                 0
# Country                  346
# State                    440
# City                     440
# has_company_profile        0
# dtype: int64

# %%
df['description'] = df['description'].fillna('No Description')
df['salary_range'] = df['salary_range'].fillna('0')
df['requirements'] = df['requirements'].fillna('Unknown')
df['benefits'] = df['benefits'].fillna('Unknown')
df['employment_type'] = df['employment_type'].fillna('Unknown')
df['required_experience'] = df['required_experience'].fillna('Unknown')
df['required_education'] = df['required_education'].fillna('Unknown')
df['industry'] = df['industry'].fillna('Unknown')
df['Country'] = df['Country'].fillna('Unknown')
df['State'] = df['State'].fillna('Unknown')
df['City'] = df['City'].fillna('Unknown')

# %%
df.isna().sum()
# Out:
# title                  0
# salary_range           0
# description            0
# requirements           0
# benefits               0
# telecommuting          0
# has_company_logo       0
# has_questions          0
# employment_type        0
# required_experience    0
# required_education     0
# industry               0
# function               0
# fraudulent             0
# Country                0
# State                  0
# City                   0
# has_company_profile    0
# dtype: int64

# %%
# create new csv file

df.to_csv('postingwithSalary.csv', index=False)

# %%
# importing data from file 'postingwithSalary.csv'

df = pd.read_csv("./postingwithSalary.csv")

# %%
df.head(2)
# Out:
#                                        title salary_range  \
# 0                           Marketing Intern            0
# 1  Customer Service - Cloud Video Production            0
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
#
#                                             benefits  telecommuting  \
# 0                                            Unknown              0
# 1  What you will get from usThrough being part of...              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
#
# ...

# %%
df.isna().sum()
# Out:
# title                  0
# salary_range           0
# description            0
# requirements           0
# benefits               0
# telecommuting          0
# has_company_logo       0
# has_questions          0
# employment_type        0
# required_experience    0
# required_education     0
# industry               0
# function               0
# fraudulent             0
# Country                0
# State                  0
# City                   0
# has_company_profile    0
# dtype: int64

# %%
import regex as re
import regex as re

df['title'] = df['title'].str.lower()
df['title'] = df['title'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['description'] = df['description'].str.lower()
df['description'] = df['description'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['requirements'] = df['requirements'].str.lower()
df['requirements'] = df['requirements'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['benefits'] = df['benefits'].str.lower()
df['benefits'] = df['benefits'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['employment_type'] = df['employment_type'].str.lower()
df['employment_type'] = df['employment_type'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['required_experience'] = df['required_experience'].str.lower()
df['required_experience'] = df['required_experience'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['required_education'] = df['required_education'].str.lower()
df['required_education'] = df['required_education'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

df['industry'] = df['industry'].str.lower()
df['industry'] = df['industry'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

# %%
#Tokenizing description series
import nltk 
from nltk.tokenize import word_tokenize
nltk.download('punkt')

df['title_token'] = df['title'].apply(word_tokenize)

df['description_token'] = df['description'].apply(word_tokenize)

df['requirements_token'] = df['requirements'].apply(word_tokenize)

df['benefits_token'] = df['benefits'].apply(word_tokenize)

df['employment_type_token'] = df['employment_type'].apply(word_tokenize)

df['required_experience_token'] = df['required_experience'].apply(word_tokenize)

df['required_education_token'] = df['required_education'].apply(word_tokenize)

df['industry_token'] = df['industry'].str.lower()

df.head(2)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\maste\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True
#                                       title salary_range  \
# 0                          marketing intern            0
# 1  customer service  cloud video production            0
#
#                                          description  \
# 0  food52 a fastgrowing james beard awardwinning ...
# 1  organised  focused  vibrant  awesomedo you hav...
#
#                                         requirements  \
# 0  experience with content management systems a m...
# 1  what we expect from youyour key responsibility...
#
#                                             benefits  telecommuting  \
# 0                                            unknown              0
# 1  what you will get from usthrough being part of...              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# ...

# %%
#remove stopwords from description
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

df['title_clean'] = df['title_token'].apply(lambda x: [word for word in x if word not in stop_words])

df['description_clean'] = df['description_token'].apply(lambda x: [word for word in x if word not in stop_words])

df['requirements_clean'] = df['requirements_token'].apply(lambda x: [word for word in x if word not in stop_words])

df['benefits_clean'] = df['benefits_token'].apply(lambda x: [word for word in x if word not in stop_words])

df['employment_type_clean'] = df['employment_type_token'].apply(lambda x: [word for word in x if word not in stop_words])

df['required_experience_clean'] = df['required_experience_token'].apply(lambda x: [word for word in x if word not in stop_words])

df['required_education_clean'] = df['required_education_token'].apply(lambda x: [word for word in x if word not in stop_words])

df['industry_clean'] = df['industry_token'].apply(lambda x: [word for word in x if word not in stop_words])

df.head(2)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\maste\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True
#                                       title salary_range  \
# 0                          marketing intern            0
# 1  customer service  cloud video production            0
#
#                                          description  \
# 0  food52 a fastgrowing james beard awardwinning ...
# 1  organised  focused  vibrant  awesomedo you hav...
#
#                                         requirements  \
# 0  experience with content management systems a m...
# 1  what we expect from youyour key responsibility...
#
#                                             benefits  telecommuting  \
# 0                                            unknown              0
# 1  what you will get from usthrough being part of...              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# ...

# %%
#join string back for analysis

def combine_words(words_list):
    # Combine the words into a single string with spaces
    combined_string = " ".join(words_list)
    
    return combined_string


df["Total"] = df["description_clean"].apply(combine_words)

df['title_total'] = df['title_clean'].apply(combine_words)

df['description_total'] = df['description_clean'].apply(combine_words)

df['requirements_total'] = df['requirements_clean'].apply(combine_words)

df['benefits_total'] = df['benefits_clean'].apply(combine_words)

df['employment_type_total'] = df['employment_type_clean'].apply(combine_words)

df['required_experience_total'] = df['required_experience_clean'].apply(combine_words)

df['required_education_total'] = df['required_education_clean'].apply(combine_words)

df['industry_total'] = df['industry_clean'].apply(combine_words)


# Print the DataFrame
df.head()
# Out:
#                                       title salary_range  \
# 0                          marketing intern            0
# 1  customer service  cloud video production            0
# 2     commissioning machinery assistant cma            0
# 3          account executive  washington dc            0
# 4                       bill review manager            0
#
#                                          description  \
# 0  food52 a fastgrowing james beard awardwinning ...
# 1  organised  focused  vibrant  awesomedo you hav...
# 2  our client located in houston is actively seek...
# 3  the company esri  environmental systems resear...
# 4  job title itemization review managerlocation f...
#
#                                         requirements  \
# 0  experience with content management systems a m...
# 1  what we expect from youyour key responsibility...
# 2  implement precommissioning and commissioning p...
# 3  education bachelors or masters in gis business...
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

transformer = TfidfTransformer(smooth_idf = False)
count_vectorizer = CountVectorizer(ngram_range = (1,2))

# %%
train_counts = count_vectorizer.fit_transform(df['Total'].values)

train_tfidf = transformer.fit_transform(train_counts)
train_counts




# df['description_cv'] = cv.fit_transform(df.description).toarray()

# df['title_cv'] = df['title']

# # df['description_cv'] = df['description']

# df['requirements_cv'] = cv.fit_transform(df['requirements'])
# df['requirements_cv'] = df['requirements_cv'].toarray()

# df['benefits_cv'] = df['benefits']

# df['employment_type_cv'] = df['employment_type']

# df['required_experience_cv'] = df['required_experience']

# df['required_education_cv'] = df['required_education']

# df['industry_cv'] = df['industry']
# Out:
# <17880x777343 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3388569 stored elements in Compressed Sparse Row format>

# %%
X = train_tfidf
y = df['fraudulent']

# %% [markdown]
# ```
# # SMOTE Way 1:
# ```

# %%
from collections import Counter
Counter(y)
# Out:
# Counter({0: 17014, 1: 866})

# %%
from imblearn.over_sampling import SMOTE
smo = SMOTE(random_state=42)

# %%
X_smo,y_smo = smo.fit_resample(X,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25860/1672220941.py in <module>
# ----> 1 X_smo,y_smo = smo.fit_resample(X,y)
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      86         )
#      87
# ---> 88         output = self._fit_resample(X, y)
#      89
#      90         y_ = (
#
# ~\anaconda3\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     353
#     354             self.nn_k_.fit(X_class)
# --> 355             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
# ...

# %%
Counter(y_smo)
# Out:
# Counter({0: 17014, 1: 17014})

# %%
y_smo.shape
# Out:
# (34028,)

# %%
X_smo.shape
# Out:
# (34028, 777343)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_smo,y_smo, test_size = 0.2, random_state = 3)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

Adab = AdaBoostClassifier(DecisionTreeClassifier(max_depth = 3), n_estimators = 5)
Adab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=3),
#                    n_estimators=5)

# %%
print("score for training dataset:",Adab.score(X_train, y_train))
print("score for test dataset:",Adab.score(X_test, y_test))
print("predict:",Adab.predict(X_test))
# Out:
# score for training dataset: 0.8310924987142753
# score for test dataset: 0.83191301792536
# predict: [1 1 1 ... 1 1 0]

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE

# Generate a sample dataset with imbalanced classes
X, y = make_classification(n_samples=10000, n_features=20, weights=[0.9], random_state=42)

# Print the class distribution
print('Original class distribution:')
print(pd.Series(y).value_counts())
# Out:
# Original class distribution:
# 0    8969
# 1    1031
# dtype: int64

# %%
# Apply SMOTE to balance the classes
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Print the class distribution after applying SMOTE
print('Class distribution after applying SMOTE:')
print(pd.Series(y_resampled).value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15280/3693560192.py in <module>
#       1 # Apply SMOTE to balance the classes
#       2 smote = SMOTE(random_state=42)
# ----> 3 X_resampled, y_resampled = smote.fit_resample(X, y)
#       4
#       5 # Print the class distribution after applying SMOTE
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      86         )
#      87
# ---> 88         output = self._fit_resample(X, y)
#      89
#      90         y_ = (
#
# ~\anaconda3\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     353
# ...

# %%
from imblearn.over_sampling import SMOTE

# Create some example data
X = [[1, 2], [3, 4], [1, 2], [3, 4], [5, 6], [7, 8]]
y = [1, 0, 0, 1, 1, 1]

# Apply SMOTE to balance the classes
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

# Print the class distribution after applying SMOTE
import collections
print(collections.Counter(y_resampled))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15280/3610881282.py in <module>
#       7 # Apply SMOTE to balance the classes
#       8 smote = SMOTE()
# ----> 9 X_resampled, y_resampled = smote.fit_resample(X, y)
#      10
#      11 # Print the class distribution after applying SMOTE
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      86         )
#      87
# ---> 88         output = self._fit_resample(X, y)
#      89
#      90         y_ = (
#
# ~\anaconda3\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     353
# ...
